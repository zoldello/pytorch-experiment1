# %% [markdown]
# <a href="https://colab.research.google.com/github/zoldello/pytorch-experiment1/blob/main/pytorch_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
